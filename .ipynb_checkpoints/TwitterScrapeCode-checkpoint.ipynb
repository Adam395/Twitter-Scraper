# %%
#Import requisite modules
import sys
import pandas as pd
import datetime
import os
from twitterscraper import query_tweets #if you haven't installed this module, run 'pip install twitterscraper' in your notebook
#---------------------------------------------------------------------

query_list = [ #This is our sample list, add or subtract as you see fit!
    'COVID',
    'COVID-19',
    'Corona',
    'Coronavirus',
    'Rona',
    'Quarantine',
    '#COVID',
    '#COVID-19',
    '#quarantine',
    '#Quarantine',
    '#covid19'
]
#--------------------------------------------------------------------

#Credit to Danielle Medellin, DSI11-NYC for the below implementation of custom parameter dictionary support
custom_params = {'Houston':{'city' : 'Houston',
                         'lat'  : 29.760427,
                         'long' : -95.369804,
                         'radius': '15mi',
                         'queries' : ['rona','corona','covid']},
              'Detroit': {'city' : 'Detroit',
                          'lat'  : 42.331429,
                          'long' : -83.045753,
                          'radius' : '10mi',
                         'queries': ['stonks','tom nook','animal crossing']}
             }
#--------------------------------------------------------------------

#Get tweets without geolocation
def get_tweets(query): 
    tweets = {}
    count = 0 #Sets the index generator
    for tweet in query_tweets(query,10,begindate=datetime.date(2019,12,1)): #Runs 100 pings, 
        chirp = {}
        chirp['tweet_id'] = tweet.tweet_id
        chirp['username'] = tweet.username
        chirp['text'] = tweet.text
        chirp['tweet_date'] = tweet.timestamp
        chirp['search_term'] = query
        chirp['city'] = 'n/a'
        chirp['long'] = 'n/a' #fills in n/a value for all geolocation columns to avoid feature issues later.
        chirp['lat'] = 'n/a'
        chirp['radius'] = 'n/a'
        tweets.update({count : chirp})
        count += 1
    return tweets
#--------------------------------------------------------------------

#Get tweets with geolocation
def get_tweets_geoloc(query, lat, long, radius): #Geolocation parameters defined by user in master function or dictionary
    tweets = {}
    count = 0
    for tweet in query_tweets(f"{query}, geocode:{lat},{long},{radius}",10,begindate=datetime.date(2019,12,1)):
        chirp = {} #Generates tweet dictionary by calling on generated 'tweet' object attributes
        chirp['tweet_id'] = tweet.tweet_id
        chirp['username'] = tweet.username
        chirp['text'] = tweet.text
        chirp['tweet_date'] = tweet.timestamp
        chirp['search_term'] = query
        chirp['lat'] = lat
        chirp['long'] = long
        chirp['radius'] = radius
        tweets.update({count : chirp})
        count += 1 #increments index up by 1 for later dataframe implementation
    return tweets
#--------------------------------------------------------------------

#Generate dataframe from "tweets" dictionary generated after each query
def make_dataframe(dictionary):
    df = pd.DataFrame.from_dict(dictionary, orient='index') 
    return df
#--------------------------------------------------------------------

#Query function using custom parameters
#Credit Danielle Medellin for this code block section
def get_query_dataframe_cp(custom_params):
    query_df = pd.DataFrame() #instantiate an empty dataframe
    for key in custom_params.keys():
        for query in custom_params[key]['queries']:
            tweets = get_tweets_geoloc(query,custom_params[key]['lat'],custom_params[key]['long'],custom_params[key]['radius'])
            df = make_dataframe(tweets)
            query_df = pd.concat([query_df,df],ignore_index = True)
    return query_df
#---------------------------------------------------------------

#Query function with geolocation but no custom parameters
def get_query_dataframe_geo(list_of_queries):
    query_df = pd.DataFrame() #instantiate an empty dataframe
    for query in list_of_queries:
            tweets = get_tweets_geoloc(query,lat,long,radius)
            df = make_dataframe(tweets)
            qdf = pd.concat([query_df,df],ignore_index = True)
    return query_df
#-------------------------------------------------------------------

#Query function with no custom anything
def get_query_dataframe(list_of_queries):
    query_df = pd.DataFrame() #instantiate an empty dataframe
    for query in list_of_queries:
            tweets = get_tweets(query)
            df = make_dataframe(tweets)
            dataset = pd.concat([query_df,df],ignore_index = True)
    return query_df
#------------------------------------------------------------------

#Master function
def get_dataset():
    #Paramter switches
    custom_params_switch = input("Are you using a custom parameter dictionary?")
    export_csv_switch = input("Do you want to export the final dataframe to csv?")
    
    #Custom parameter switch block
    if str.lower(custom_params_switch) == 'yes':
        dataset = get_query_dataframe_cp(custom_params)
    else:
        geo_switch = input("Are you using geolocation?")
        if str.lower(geo_switch) == 'yes':
            lat = float(input("Input Latitude:")) #Converts string input latitude to float value
            long = float(input("Input Longitude:"))
            radius = input("Input radius and unit:")
            dataset = get_query_dataframe_geo(query_list, lat, long, radius)
        else:
            dataset = get_query_datarame(query_list)
    
    #CSV export switch block
    if str.lower(export_csv_switch) == 'yes':
        custom_csv_name = input("Input CSV export file name:") #user input line for export name
        if os.path.exists('datasets') == True: # check if datasets folder exists, if yes pass, if no, create folder
            pass
        else:
            os.mkdir('datasets')
        dataset.to_csv(f"./datasets/{custom_csv_name}.csv", index = False) #write csv to datasets folder
        print("Export complete")
    else:
        return dataset

# %%
get_dataset()
# Out:
# Are you using a custom parameter dictionary? yes
# Do you want to export the final dataframe to csv? yes
# INFO: queries: ['rona, geocode:29.760427,-95.369804,15mi since:2019-12-01 until:2019-12-08', 'rona, geocode:29.760427,-95.369804,15mi since:2019-12-08 until:2019-12-16', 'rona, geocode:29.760427,-95.369804,15mi since:2019-12-16 until:2019-12-24', 'rona, geocode:29.760427,-95.369804,15mi since:2019-12-24 until:2020-01-01', 'rona, geocode:29.760427,-95.369804,15mi since:2020-01-01 until:2020-01-09', 'rona, geocode:29.760427,-95.369804,15mi since:2020-01-09 until:2020-01-17', 'rona, geocode:29.760427,-95.369804,15mi since:2020-01-17 until:2020-01-25', 'rona, geocode:29.760427,-95.369804,15mi since:2020-01-25 until:2020-02-02', 'rona, geocode:29.760427,-95.369804,15mi since:2020-02-02 until:2020-02-10', 'rona, geocode:29.760427,-95.369804,15mi since:2020-02-10 until:2020-02-18', 'rona, geocode:29.760427,-95.369804,15mi since:2020-02-18 until:2020-02-25', 'rona, geocode:29.760427,-95.369804,15mi since:2020-02-25 until:2020-03-04', 'rona, geocode:29.760427,-95.369804,15mi since:2020-03-04 until:2020-03-12', 'rona, geocode:29.760427,-95.369804,15mi since:2020-03-12 until:2020-03-20', 'rona, geocode:29.760427,-95.369804,15mi since:2020-03-20 until:2020-03-28', 'rona, geocode:29.760427,-95.369804,15mi since:2020-03-28 until:2020-04-05', 'rona, geocode:29.760427,-95.369804,15mi since:2020-04-05 until:2020-04-13', 'rona, geocode:29.760427,-95.369804,15mi since:2020-04-13 until:2020-04-21', 'rona, geocode:29.760427,-95.369804,15mi since:2020-04-21 until:2020-04-29', 'rona, geocode:29.760427,-95.369804,15mi since:2020-04-29 until:2020-05-07']
# INFO: Got 1 tweets (1 new).
# INFO: Got 2 tweets (1 new).
# INFO: Got 3 tweets (1 new).
# INFO: Got 4 tweets (1 new).
# INFO: Got 5 tweets (1 new).
# INFO: Got 6 tweets (1 new).
# INFO: Got 24 tweets (18 new).
# INFO: Got 42 tweets (18 new).
# INFO: Got 62 tweets (20 new).
# INFO: Got 80 tweets (18 new).
# INFO: Got 99 tweets (19 new).
# INFO: Got 117 tweets (18 new).
# INFO: Got 136 tweets (19 new).
# INFO: Got 153 tweets (17 new).
# INFO: Got 153 tweets (0 new).
# INFO: Got 153 tweets (0 new).
# INFO: Got 153 tweets (0 new).
# INFO: Got 153 tweets (0 new).
# INFO: Got 153 tweets (0 new).
# INFO: Got 153 tweets (0 new).
# INFO: queries: ['corona, geocode:29.760427,-95.369804,15mi since:2019-12-01 until:2019-12-08', 'corona, geocode:29.760427,-95.369804,15mi since:2019-12-08 until:2019-12-16', 'corona, geocode:29.760427,-95.369804,15mi since:2019-12-16 until:2019-12-24', 'corona, geocode:29.760427,-95.369804,15mi since:2019-12-24 until:2020-01-01', 'corona, geocode:29.760427,-95.369804,15mi since:2020-01-01 until:2020-01-09', 'corona, geocode:29.760427,-95.369804,15mi since:2020-01-09 until:2020-01-17', 'corona, geocode:29.760427,-95.369804,15mi since:2020-01-17 until:2020-01-25', 'corona, geocode:29.760427,-95.369804,15mi since:2020-01-25 until:2020-02-02', 'corona, geocode:29.760427,-95.369804,15mi since:2020-02-02 until:2020-02-10', 'corona, geocode:29.760427,-95.369804,15mi since:2020-02-10 until:2020-02-18', 'corona, geocode:29.760427,-95.369804,15mi since:2020-02-18 until:2020-02-25', 'corona, geocode:29.760427,-95.369804,15mi since:2020-02-25 until:2020-03-04', 'corona, geocode:29.760427,-95.369804,15mi since:2020-03-04 until:2020-03-12', 'corona, geocode:29.760427,-95.369804,15mi since:2020-03-12 until:2020-03-20', 'corona, geocode:29.760427,-95.369804,15mi since:2020-03-20 until:2020-03-28', 'corona, geocode:29.760427,-95.369804,15mi since:2020-03-28 until:2020-04-05', 'corona, geocode:29.760427,-95.369804,15mi since:2020-04-05 until:2020-04-13', 'corona, geocode:29.760427,-95.369804,15mi since:2020-04-13 until:2020-04-21', 'corona, geocode:29.760427,-95.369804,15mi since:2020-04-21 until:2020-04-29', 'corona, geocode:29.760427,-95.369804,15mi since:2020-04-29 until:2020-05-07']
# INFO: Got 3 tweets (3 new).
# INFO: Got 10 tweets (7 new).
# INFO: Got 15 tweets (5 new).
# INFO: Got 21 tweets (6 new).
# INFO: Got 24 tweets (3 new).
# INFO: Got 32 tweets (8 new).
# INFO: Got 40 tweets (8 new).
# INFO: Got 59 tweets (19 new).
# INFO: Got 79 tweets (20 new).
# INFO: Got 99 tweets (20 new).
# INFO: Got 118 tweets (19 new).
# INFO: Got 137 tweets (19 new).
# INFO: Got 156 tweets (19 new).
# INFO: Got 174 tweets (18 new).
# INFO: Got 192 tweets (18 new).
# INFO: Got 211 tweets (19 new).
# INFO: Got 231 tweets (20 new).
# INFO: Got 249 tweets (18 new).
# INFO: Got 269 tweets (20 new).
# INFO: Got 288 tweets (19 new).
new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: Got 12 tweets (0 new).
# INFO: queries: ['tom nook, geocode:42.331429,-83.045753,10mi since:2019-12-01 until:2019-12-08', 'tom nook, geocode:42.331429,-83.045753,10mi since:2019-12-08 until:2019-12-16', 'tom nook, geocode:42.331429,-83.045753,10mi since:2019-12-16 until:2019-12-24', 'tom nook, geocode:42.331429,-83.045753,10mi since:2019-12-24 until:2020-01-01', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-01-01 until:2020-01-09', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-01-09 until:2020-01-17', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-01-17 until:2020-01-25', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-01-25 until:2020-02-02', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-02-02 until:2020-02-10', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-02-10 until:2020-02-18', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-02-18 until:2020-02-25', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-02-25 until:2020-03-04', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-03-04 until:2020-03-12', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-03-12 until:2020-03-20', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-03-20 until:2020-03-28', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-03-28 until:2020-04-05', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-04-05 until:2020-04-13', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-04-13 until:2020-04-21', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-04-21 until:2020-04-29', 'tom nook, geocode:42.331429,-83.045753,10mi since:2020-04-29 until:2020-05-07']
# INFO: Got 1 tweets (1 new).
# INFO: Got 2 tweets (1 new).
# INFO: Got 5 tweets (3 new).
# INFO: Got 7 tweets (2 new).
# INFO: Got 9 tweets (2 new).
# INFO: Got 10 tweets (1 new).
# INFO: Got 12 tweets (2 new).
# INFO: Got 14 tweets (2 new).
# INFO: Got 15 tweets (1 new).
# INFO: Got 20 tweets (5 new).
# INFO: Got 23 tweets (3 new).
# INFO: Got 41 tweets (18 new).
# INFO: Got 41 tweets (0 new).
# INFO: Got 41 tweets (0 new).
# INFO: Got 41 tweets (0 new).
# INFO: Got 41 tweets (0 new).
# INFO: Got 41 tweets (0 new).
# INFO: Got 41 tweets (0 new).
# INFO: Got 41 tweets (0 new).
# INFO: Got 41 tweets (0 new).
# INFO: queries: ['animal crossing, geocode:42.331429,-83.045753,10mi since:2019-12-01 until:2019-12-08', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2019-12-08 until:2019-12-16', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2019-12-16 until:2019-12-24', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2019-12-24 until:2020-01-01', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-01-01 until:2020-01-09', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-01-09 until:2020-01-17', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-01-17 until:2020-01-25', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-01-25 until:2020-02-02', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-02-02 until:2020-02-10', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-02-10 until:2020-02-18', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-02-18 until:2020-02-25', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-02-25 until:2020-03-04', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-03-04 until:2020-03-12', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-03-12 until:2020-03-20', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-03-20 until:2020-03-28', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-03-28 until:2020-04-05', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-04-05 until:2020-04-13', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-04-13 until:2020-04-21', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-04-21 until:2020-04-29', 'animal crossing, geocode:42.331429,-83.045753,10mi since:2020-04-29 until:2020-05-07']
# INFO: Got 1 tweets (1 new).
# INFO: Got 2 tweets (1 new).
# INFO: Got 4 tweets (2 new).
# INFO: Got 5 tweets (1 new).
# INFO: Got 7 tweets (2 new).
# INFO: Got 8 tweets (1 new).
# INFO: Got 10 tweets (2 new).
# INFO: Got 11 tweets (1 new).
# INFO: Got 12 tweets (1 new).
# INFO: Got 16 tweets (4 new).
# INFO: Got 23 tweets (7 new).
# INFO: Got 33 tweets (10 new).
# INFO: Got 39 tweets (6 new).
# INFO: Got 47 tweets (8 new).
# INFO: Got 56 tweets (9 new).
# INFO: Got 70 tweets (14 new).
# INFO: Got 85 tweets (15 new).
# INFO: Got 105 tweets (20 new).
# INFO: Got 125 tweets (20 new).
# INFO: Got 144 tweets (19 new).
# Input CSV export file name: scrape
